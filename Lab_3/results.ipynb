# %% [markdown]
# ## Bài 1

# %%
# !python main.py --model LSTM --data uit_vsfc --num_epochs 10 --lr 0.0005
# Out:
# Epoch 1/10 | Train Loss: 0.6094 | Val Loss: 0.4787 | Val F1: 0.5401
# Best model saved at epoch 1
# Epoch 2/10 | Train Loss: 0.4614 | Val Loss: 0.4413 | Val F1: 0.6116
# Best model saved at epoch 2
# Epoch 3/10 | Train Loss: 0.4104 | Val Loss: 0.3783 | Val F1: 0.7195
# Best model saved at epoch 3
# Epoch 4/10 | Train Loss: 0.3794 | Val Loss: 0.3757 | Val F1: 0.7172
# Epoch 5/10 | Train Loss: 0.3632 | Val Loss: 0.3729 | Val F1: 0.7275
# Best model saved at epoch 5
# Epoch 6/10 | Train Loss: 0.3378 | Val Loss: 0.3622 | Val F1: 0.7339
# Best model saved at epoch 6
# Epoch 7/10 | Train Loss: 0.3244 | Val Loss: 0.3798 | Val F1: 0.7185
# Epoch 8/10 | Train Loss: 0.3070 | Val Loss: 0.3768 | Val F1: 0.7417
# Best model saved at epoch 8
# Epoch 9/10 | Train Loss: 0.3010 | Val Loss: 0.3595 | Val F1: 0.7423
# Best model saved at epoch 9
# Epoch 10/10 | Train Loss: 0.2838 | Val Loss: 0.3541 | Val F1: 0.7488
# Best model saved at epoch 10
# ----- Test Results ----
# Test F1 Score: 0.7650
# ...

# %% [markdown]
# ## Bài 2

# %%
# !python main.py --model GRU --data uit_vsfc --num_epochs 10 --lr 0.0005
# Out:
# Epoch 1/10 | Train Loss: 0.5573 | Val Loss: 0.4233 | Val F1: 0.6480
# Best model saved at epoch 1
# Epoch 2/10 | Train Loss: 0.4151 | Val Loss: 0.3759 | Val F1: 0.6938
# Best model saved at epoch 2
# Epoch 3/10 | Train Loss: 0.3773 | Val Loss: 0.3586 | Val F1: 0.7153
# Best model saved at epoch 3
# Epoch 4/10 | Train Loss: 0.3576 | Val Loss: 0.3453 | Val F1: 0.7449
# Best model saved at epoch 4
# Epoch 5/10 | Train Loss: 0.3312 | Val Loss: 0.3492 | Val F1: 0.7199
# Epoch 6/10 | Train Loss: 0.3135 | Val Loss: 0.3493 | Val F1: 0.7466
# Best model saved at epoch 6
# Epoch 7/10 | Train Loss: 0.3086 | Val Loss: 0.3500 | Val F1: 0.7591
# Best model saved at epoch 7
# Epoch 8/10 | Train Loss: 0.2900 | Val Loss: 0.3538 | Val F1: 0.7484
# Epoch 9/10 | Train Loss: 0.2769 | Val Loss: 0.3445 | Val F1: 0.7542
# Epoch 10/10 | Train Loss: 0.2570 | Val Loss: 0.3579 | Val F1: 0.7637
# Best model saved at epoch 10
# ----- Test Results ----
# Test F1 Score: 0.7582
# Test Classification Report:
# ...

# %% [markdown]
# ## Bài 3

# %%
# !python main.py --model BiLSTM --data phonert --num_epochs 20 --lr 0.0005
# Out:
# Epoch 1/20 | Train Loss: 1.0836 | Val Loss: 1.0789 | Val F1: 0.0451
# Best model saved at epoch 1
# Epoch 2/20 | Train Loss: 0.6436 | Val Loss: 0.4204 | Val F1: 0.3214
# Best model saved at epoch 2
# Epoch 3/20 | Train Loss: 0.2814 | Val Loss: 0.2601 | Val F1: 0.4360
# Best model saved at epoch 3
# Epoch 4/20 | Train Loss: 0.1902 | Val Loss: 0.1997 | Val F1: 0.5794
# Best model saved at epoch 4
# Epoch 5/20 | Train Loss: 0.1454 | Val Loss: 0.1893 | Val F1: 0.6203
# Best model saved at epoch 5
# Epoch 6/20 | Train Loss: 0.1204 | Val Loss: 0.1704 | Val F1: 0.6204
# Best model saved at epoch 6
# Epoch 7/20 | Train Loss: 0.1041 | Val Loss: 0.1674 | Val F1: 0.6387
# Best model saved at epoch 7
# Epoch 8/20 | Train Loss: 0.0908 | Val Loss: 0.1553 | Val F1: 0.6609
# Best model saved at epoch 8
# Epoch 9/20 | Train Loss: 0.0776 | Val Loss: 0.1439 | Val F1: 0.7077
# Best model saved at epoch 9
# Epoch 10/20 | Train Loss: 0.0726 | Val Loss: 0.1560 | Val F1: 0.7130
# ...
