# %% [markdown]
# # Bài 1

# %%
# !python main.py --model CLS --data uit_viocd --num_epochs 10 --lr 0.0005
# Out:
# Epoch 1/10 | Train Loss: 0.7270 | Val Loss: 0.4418 | Val F1: 0.8021
# Best model saved at epoch 1
# Epoch 2/10 | Train Loss: 0.3262 | Val Loss: 0.3482 | Val F1: 0.8671
# Best model saved at epoch 2
# Epoch 3/10 | Train Loss: 0.2097 | Val Loss: 0.3302 | Val F1: 0.8856
# Best model saved at epoch 3
# Epoch 4/10 | Train Loss: 0.1551 | Val Loss: 0.3840 | Val F1: 0.8816
# Epoch 5/10 | Train Loss: 0.1191 | Val Loss: 0.3774 | Val F1: 0.8829
# Epoch 6/10 | Train Loss: 0.0873 | Val Loss: 0.4238 | Val F1: 0.8914
# Best model saved at epoch 6
# Epoch 7/10 | Train Loss: 0.0672 | Val Loss: 0.5345 | Val F1: 0.8894
# Epoch 8/10 | Train Loss: 0.0554 | Val Loss: 0.4104 | Val F1: 0.8983
# Best model saved at epoch 8
# Epoch 9/10 | Train Loss: 0.0471 | Val Loss: 0.6236 | Val F1: 0.8896
# Epoch 10/10 | Train Loss: 0.0506 | Val Loss: 0.4645 | Val F1: 0.8986
# Best model saved at epoch 10
# ----- Test Results ----
# Test F1 Score: 0.9111
# Test Classification Report:
# ...

# %% [markdown]
# # Bài 2

# %%
# !python main.py --model NER --data phonert --num_epochs 20 --lr 0.0005
# Out:
# Epoch 1/20 | Train Loss: 0.7993 | Val Loss: 0.5999 | Val F1: 0.8050
# Best model saved at epoch 1
# Epoch 2/20 | Train Loss: 0.3944 | Val Loss: 0.4565 | Val F1: 0.8567
# Best model saved at epoch 2
# Epoch 3/20 | Train Loss: 0.2907 | Val Loss: 0.3968 | Val F1: 0.8788
# Best model saved at epoch 3
# Epoch 4/20 | Train Loss: 0.2374 | Val Loss: 0.3630 | Val F1: 0.8919
# Best model saved at epoch 4
# Epoch 5/20 | Train Loss: 0.1986 | Val Loss: 0.3403 | Val F1: 0.9022
# Best model saved at epoch 5
# Epoch 6/20 | Train Loss: 0.1719 | Val Loss: 0.3336 | Val F1: 0.9050
# Best model saved at epoch 6
# Epoch 7/20 | Train Loss: 0.1499 | Val Loss: 0.3391 | Val F1: 0.9068
# Best model saved at epoch 7
# Epoch 8/20 | Train Loss: 0.1331 | Val Loss: 0.3293 | Val F1: 0.9094
# Best model saved at epoch 8
# Epoch 9/20 | Train Loss: 0.1187 | Val Loss: 0.3437 | Val F1: 0.9107
# Best model saved at epoch 9
# Epoch 10/20 | Train Loss: 0.1087 | Val Loss: 0.3515 | Val F1: 0.9113
# ...
