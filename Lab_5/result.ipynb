# %% [markdown]
# # Bài 1

# %%
# !python main.py --model CLS --data uit_viocd --num_epochs 20 --lr 0.0005
# Out:
# Epoch 1/20 | Train Loss: 0.7625 | Val Loss: 0.4283 | Val F1: 0.8019
# Best model saved at epoch 1
# Epoch 2/20 | Train Loss: 0.3611 | Val Loss: 0.3273 | Val F1: 0.8703
# Best model saved at epoch 2
# Epoch 3/20 | Train Loss: 0.2274 | Val Loss: 0.3056 | Val F1: 0.8754
# Best model saved at epoch 3
# Epoch 4/20 | Train Loss: 0.1675 | Val Loss: 0.3198 | Val F1: 0.8882
# Best model saved at epoch 4
# Epoch 5/20 | Train Loss: 0.1258 | Val Loss: 0.3275 | Val F1: 0.8887
# Best model saved at epoch 5
# Epoch 6/20 | Train Loss: 0.1096 | Val Loss: 0.3663 | Val F1: 0.8916
# Best model saved at epoch 6
# Epoch 7/20 | Train Loss: 0.0861 | Val Loss: 0.3722 | Val F1: 0.8904
# Epoch 8/20 | Train Loss: 0.0603 | Val Loss: 0.4388 | Val F1: 0.8880
# Epoch 9/20 | Train Loss: 0.0486 | Val Loss: 0.4933 | Val F1: 0.8935
# Best model saved at epoch 9
# Epoch 10/20 | Train Loss: 0.0372 | Val Loss: 0.4845 | Val F1: 0.8944
# Best model saved at epoch 10
# ...

# %% [markdown]
# # Bài 2

# %%
# !python main.py --model NER --data phonert --num_epochs 20 --lr 0.0005
# Out:
# Epoch 1/20 | Train Loss: 0.7936 | Val Loss: 0.5902 | Val F1: 0.8085
# Best model saved at epoch 1
# Epoch 2/20 | Train Loss: 0.3917 | Val Loss: 0.4368 | Val F1: 0.8601
# Best model saved at epoch 2
# Epoch 3/20 | Train Loss: 0.2858 | Val Loss: 0.3721 | Val F1: 0.8836
# Best model saved at epoch 3
# Epoch 4/20 | Train Loss: 0.2301 | Val Loss: 0.3425 | Val F1: 0.8957
# Best model saved at epoch 4
# Epoch 5/20 | Train Loss: 0.1932 | Val Loss: 0.3201 | Val F1: 0.9029
# Best model saved at epoch 5
# Epoch 6/20 | Train Loss: 0.1666 | Val Loss: 0.3137 | Val F1: 0.9056
# Best model saved at epoch 6
# Epoch 7/20 | Train Loss: 0.1487 | Val Loss: 0.3117 | Val F1: 0.9065
# Best model saved at epoch 7
# Epoch 8/20 | Train Loss: 0.1318 | Val Loss: 0.3101 | Val F1: 0.9103
# Best model saved at epoch 8
# Epoch 9/20 | Train Loss: 0.1167 | Val Loss: 0.3265 | Val F1: 0.9075
# Epoch 10/20 | Train Loss: 0.1058 | Val Loss: 0.3282 | Val F1: 0.9092
# ...
