# %% [markdown]
# # Bài 1

# %%
# !python main.py --attention None --lr 0.005 --batch_size 16 --num_epochs 10
# Out:
# Epoch 1/10 | Train Loss: 2.3882 | Val Loss: 2.7416 | Val Rouge_L: 0.2842
# Best model saved at epoch 1
# Epoch 2/10 | Train Loss: 1.9744 | Val Loss: 2.5989 | Val Rouge_L: 0.3025
# Best model saved at epoch 2
# Epoch 3/10 | Train Loss: 1.8320 | Val Loss: 2.5903 | Val Rouge_L: 0.3042
# Best model saved at epoch 3
# Epoch 4/10 | Train Loss: 1.7236 | Val Loss: 2.5324 | Val Rouge_L: 0.3126
# Best model saved at epoch 4
# Epoch 5/10 | Train Loss: 1.6586 | Val Loss: 2.5165 | Val Rouge_L: 0.3080
# Epoch 6/10 | Train Loss: 1.5858 | Val Loss: 2.5816 | Val Rouge_L: 0.3122
# Epoch 7/10 | Train Loss: 1.5396 | Val Loss: 2.5993 | Val Rouge_L: 0.3139
# Best model saved at epoch 7
# Epoch 8/10 | Train Loss: 1.4840 | Val Loss: 2.6982 | Val Rouge_L: 0.3184
# Best model saved at epoch 8
# Epoch 9/10 | Train Loss: 1.4545 | Val Loss: 2.7191 | Val Rouge_L: 0.3140
# Epoch 10/10 | Train Loss: 1.4013 | Val Loss: 2.7693 | Val Rouge_L: 0.3094
# ----- Test Results ----
# Test Rouge_L Score: 0.3230

# %% [markdown]
# # Bài 2

# %%
# !python main.py --attention Bahdanau --lr 0.005 --batch_size 16 --num_epochs 10
# Out:
# Epoch 1/10 | Train Loss: 2.8200 | Val Loss: 3.4467 | Val Rouge_L: 0.1307
# Best model saved at epoch 1
# Epoch 2/10 | Train Loss: 2.6714 | Val Loss: 3.2290 | Val Rouge_L: 0.1884
# Best model saved at epoch 2
# Epoch 3/10 | Train Loss: 2.3965 | Val Loss: 3.0536 | Val Rouge_L: 0.2445
# Best model saved at epoch 3
# Epoch 4/10 | Train Loss: 2.2369 | Val Loss: 2.9187 | Val Rouge_L: 0.3089
# Best model saved at epoch 4
# Epoch 5/10 | Train Loss: 2.1158 | Val Loss: 2.8700 | Val Rouge_L: 0.2830
# Epoch 6/10 | Train Loss: 2.0325 | Val Loss: 2.7683 | Val Rouge_L: 0.2975
# Epoch 7/10 | Train Loss: 1.9577 | Val Loss: 2.7619 | Val Rouge_L: 0.2913
# Epoch 8/10 | Train Loss: 1.9053 | Val Loss: 2.7653 | Val Rouge_L: 0.2970
# Epoch 9/10 | Train Loss: 1.8617 | Val Loss: 2.7403 | Val Rouge_L: 0.2971
# Epoch 10/10 | Train Loss: 1.8304 | Val Loss: 2.7770 | Val Rouge_L: 0.3089
# Best model saved at epoch 10
# ----- Test Results ----
# Test Rouge_L Score: 0.3162

# %% [markdown]
# # Bài 3

# %%
# !python main.py --attention Luong --lr 0.005 --batch_size 16 --num_epochs 10
# Out:
# Epoch 1/10 | Train Loss: 2.7861 | Val Loss: 3.4471 | Val Rouge_L: 0.2121
# Best model saved at epoch 1
# Epoch 2/10 | Train Loss: 2.5372 | Val Loss: 3.1160 | Val Rouge_L: 0.2051
# Epoch 3/10 | Train Loss: 2.3014 | Val Loss: 2.8895 | Val Rouge_L: 0.2395
# Best model saved at epoch 3
# Epoch 4/10 | Train Loss: 2.1304 | Val Loss: 2.7734 | Val Rouge_L: 0.2898
# Best model saved at epoch 4
# Epoch 5/10 | Train Loss: 1.9905 | Val Loss: 2.7240 | Val Rouge_L: 0.3077
# Best model saved at epoch 5
# Epoch 6/10 | Train Loss: 1.8843 | Val Loss: 2.6196 | Val Rouge_L: 0.3081
# Best model saved at epoch 6
# Epoch 7/10 | Train Loss: 1.8021 | Val Loss: 2.6066 | Val Rouge_L: 0.3098
# Best model saved at epoch 7
# Epoch 8/10 | Train Loss: 1.7361 | Val Loss: 2.5926 | Val Rouge_L: 0.3182
# Best model saved at epoch 8
# Epoch 9/10 | Train Loss: 1.6804 | Val Loss: 2.6629 | Val Rouge_L: 0.3199
# Best model saved at epoch 9
# Epoch 10/10 | Train Loss: 1.6238 | Val Loss: 2.6661 | Val Rouge_L: 0.3139
# ...
