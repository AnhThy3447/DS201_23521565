# %% [markdown]
# ### Bài 1: Xây dựng mô hình LeNet.

# %%
# !python main.py --data mnist --model LeNet --num_epochs 10 --lr 0.001
# Out:
# ----- Training -----
# Epoch 1 - Loss: 0.6103
# Epoch 2 - Loss: 0.1492
# Epoch 3 - Loss: 0.1008
# Epoch 4 - Loss: 0.0783
# Epoch 5 - Loss: 0.0649
# Epoch 6 - Loss: 0.0568
# Epoch 7 - Loss: 0.0500
# Epoch 8 - Loss: 0.0431
# Epoch 9 - Loss: 0.0403
# Epoch 10 - Loss: 0.0359
#
# ----- Evaluation Results -----
# Test Loss: 0.0413
# Accuracy: 0.9873
# Precision: 0.9874
# Recall: 0.9871
# F1 Score: 0.9872

# %% [markdown]
# ### Bài 2: Xây dựng mô hình GoogLeNet.

# %%
# !python main.py --data vinafood --model GoogLeNet --num_epochs 10 --lr 0.0002
# Out:
# ----- Training -----
# Epoch 1 - Loss: 2.9857
# Epoch 2 - Loss: 2.9718
# Epoch 3 - Loss: 2.8468
# Epoch 4 - Loss: 2.7375
# Epoch 5 - Loss: 2.6497
# Epoch 6 - Loss: 2.5228
# Epoch 7 - Loss: 2.3996
# Epoch 8 - Loss: 2.3246
# Epoch 9 - Loss: 2.2398
# Epoch 10 - Loss: 2.1680
#
# ----- Evaluation Results -----
# Test Loss: 2.2354
# Accuracy: 0.2923
# Precision: 0.2289
# Recall: 0.2459
# F1 Score: 0.2123

# %% [markdown]
# ### Bài 3: Xây dựng mô hình ResNet-18.

# %%
# !python main.py --data vinafood --model ResNet18 --num_epochs 10 --lr 0.0002
# Out:
# ----- Training -----
# Epoch 1 - Loss: 2.3529
# Epoch 2 - Loss: 1.9271
# Epoch 3 - Loss: 1.6738
# Epoch 4 - Loss: 1.4855
# Epoch 5 - Loss: 1.3134
# Epoch 6 - Loss: 1.1497
# Epoch 7 - Loss: 1.0130
# Epoch 8 - Loss: 0.8585
# Epoch 9 - Loss: 0.7036
# Epoch 10 - Loss: 0.5907
#
# ----- Evaluation Results -----
# Test Loss: 1.8528
# Accuracy: 0.5322
# Precision: 0.5855
# Recall: 0.5316
# F1 Score: 0.5211

# %% [markdown]
# ### Bài 4: Sử dụng pretrained ResNet50 từ HuggingFace để fine-tune trên bộ dữ liệu VinaFood21.

# %%
# !python main.py --data vinafood --model ResNet50 --num_epochs 10 --lr 0.0002
# Out:
# ----- Training -----
# Epoch 1 - Loss: 2.2381
# Epoch 2 - Loss: 0.8033
# Epoch 3 - Loss: 0.3773
# Epoch 4 - Loss: 0.1824
# Epoch 5 - Loss: 0.1070
# Epoch 6 - Loss: 0.0610
# Epoch 7 - Loss: 0.0474
# Epoch 8 - Loss: 0.0349
# Epoch 9 - Loss: 0.0326
# Epoch 10 - Loss: 0.0284
#
# ----- Evaluation Results -----
# Test Loss: 0.7123
# Accuracy: 0.8243
# Precision: 0.8279
# Recall: 0.8297
# F1 Score: 0.8263
